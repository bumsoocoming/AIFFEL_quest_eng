# %% [markdown]
# <a href="https://colab.research.google.com/github/bumsoocoming/AIFFEL_quest_eng/blob/master/Python/Py04/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%3A%20%EB%82%B4%EA%B0%80%20%EB%A7%8C%EB%93%A0%20%ED%82%A4%EC%98%A4%EC%8A%A4%ED%81%AC%20%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]
        self.order_menu = []
        self.order_price = []

    def menu_print(self):
        for i in range(len(self.menu)):
            print(f"{i+1}. {self.menu[i]} : {self.price[i]}원")

    def menu_select(self):
        while True:
            n = int(input("\n음료 번호(종료는 0): "))
            if n == 0: break
            if 1 <= n <= len(self.menu):
                t = int(input("HOT(1) / ICE(2): "))
                self.temp = "HOT" if t == 1 else "ICE"
                self.order_menu.append(f"{self.temp} {self.menu[n-1]}")
                self.order_price.append(self.price[n-1])
            else:
                print("잘못된 번호입니다.")

    def pay(self):
        print(f"\n총액: {sum(self.order_price)}원")
        p = int(input("현금(1) / 카드(2): "))
        print("결제가 진행됩니다...")

    def table(self):
        print("-" * 20)
        for i in range(len(self.order_menu)):
            print(f"{self.order_menu[i]} : {self.order_price[i]}원")
        print(f"합계: {sum(self.order_price)}원")
        print("-" * 20)

# 실행부
cafe = Kiosk()
cafe.menu_print()
cafe.menu_select()
cafe.pay()
cafe.table()
# Out:
# 1. americano : 2000원
# 2. latte : 3000원
# 3. mocha : 3000원
# 4. yuza_tea : 2500원
# 5. green_tea : 2500원
# 6. choco_latte : 3000원
#
# 음료 번호(종료는 0): 1
# HOT(1) / ICE(2): 2
#
# 음료 번호(종료는 0): 2
# HOT(1) / ICE(2): 1
#
# 음료 번호(종료는 0): 3
# HOT(1) / ICE(2): 2
#
# 음료 번호(종료는 0): 4
# HOT(1) / ICE(2): 2
#
# 음료 번호(종료는 0): 5
# HOT(1) / ICE(2): 2
#
# 음료 번호(종료는 0): 6
# HOT(1) / ICE(2): 1
#
# 음료 번호(종료는 0): 0
#
# 총액: 16000원
# 현금(1) / 카드(2): 1
# 결제가 진행됩니다...
# --------------------
# ICE americano : 2000원
# HOT latte : 3000원
# ICE mocha : 3000원
# ICE yuza_tea : 2500원
# ICE green_tea : 2500원
# HOT choco_latte : 3000원
# 합계: 16000원
# --------------------
